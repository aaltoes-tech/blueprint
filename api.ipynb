# %%
from googleapiclient.discovery import build
from google.oauth2.credentials import Credentials
from typing import Any, List, Dict, Union
import pandas as pd

# %%
drive_folders = {
    '2021' : '0AEyh-w2iKkdPUk9PVA',
    '2018' : '0ADODK3buTEqsUk9PVA',
    '2019' : '0AKpWxivcQgJbUk9PVA',
    '2020' : '0AGqVTkC6YXbFUk9PVA',
    '2022' : '0AFNNPsrSaDEGUk9PVA',
    '2024' : '0ADYtJk1I0uR_Uk9PVA',
    '2025' : '0AGhLXRXVGCy1Uk9PVA'
}

# %%
token_path = "token.json"
scopes = ["https://www.googleapis.com/auth/drive.readonly"]
folder_id = drive_folders['2018']

creds = Credentials.from_authorized_user_file(
    str(token_path), scopes
)

service = build("drive", "v3", credentials=creds)

# %%
ALLOWED_TYPES = set(
    ['application/vnd.google-apps.presentation', 
    'application/vnd.google-apps.spreadsheet',
    'application/vnd.google-apps.document',
    'application/pdf',
    'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet',
    'application/vnd.openxmlformats-officedocument.wordprocessingml.document']
)

# %%
"application/pdf" in ALLOWED_TYPES
# Out:
# True

# %%
def fetch_files_recursive(
    service: Any, folder_id: str
) -> List[Dict[str, Union[str, List[str]]]]:
    """Fetch all files and subfolders recursively."""
    results = (
        service.files()
        .list(
            q=f"'{folder_id}' in parents",
            pageSize=1000,
            includeItemsFromAllDrives=True,
            supportsAllDrives=True,
            fields="nextPageToken, files(id, name, mimeType, parents, trashed)",
        )
        .execute()
    )
    files = results.get("files", [])
    returns = []
    for file in files:
        if file["mimeType"] == "application/vnd.google-apps.folder":
            returns.extend(fetch_files_recursive(service, file["id"]))
        else:
            if file["mimeType"] in ALLOWED_TYPES:
                print(file)
                returns.append(file)
    return returns

# %%
files_2018 = fetch_files_recursive(service, folder_id)
# Out:
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['15hSlZp-4v3RSI_P5QWcdlTfeibofLlFi'], 'id': '1Vv66Zx0prJoAm06gDjzKD-Hwu29FwFh2T1qGFcsP8sk', 'name': 'Aaltoes | Deck', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['15hSlZp-4v3RSI_P5QWcdlTfeibofLlFi'], 'id': '15dLirx6WhNDIFZMbD0pURwnq-S-L0S8nHeTBvXh3EZU', 'name': 'Ecosystem| Deck', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['15hSlZp-4v3RSI_P5QWcdlTfeibofLlFi'], 'id': '1jwyWTCQhrmQ7B-dTWv-nkmXQaovxGYa-R-TVECHTqho', 'name': 'Aaltoes | Deck', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['15hSlZp-4v3RSI_P5QWcdlTfeibofLlFi'], 'id': '1o4YOUlHO9ie_Yp0PA4UwctosNURURJtUuQhG90rJIds', 'name': 'SUTD', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['12cj81Zqs4cSmX3U3yppirfUOo182m-Hx'], 'id': '1PpqeYYsbyoo84mtdYohPOFgwIyLJB4KehlezWnnRepM', 'name': 'Aaltoes trip to California 2021 & 2022! (Responses)', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['12cj81Zqs4cSmX3U3yppirfUOo182m-Hx'], 'id': '1I1iUj6LMPeGMaX4dj3UqWx8_mQ3gwc4bY-AQi0JoJTE', 'name': "Cali'21 budget", 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['1W_ZAY5ZUKu4mR3Y4T-4lHwYtnhOfk6Pb'], 'id': '1eUC1_W1ijtmBeLlbSGIw9xnLNQOIE0Oh', 'name': 'Avis Finland Booking Terms.pdf', 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['1W_ZAY5ZUKu4mR3Y4T-4lHwYtnhOfk6Pb'], 'id': '1PcVmmWkxUI3KjYsaOnKIaepPs0nidZNX', 'name': 'Booking Details - 5. Booking Confirmation_car3.pdf', 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['1W_ZAY5ZUKu4mR3Y4T-4lHwYtnhOfk6Pb'], 'id': '1B2YwElWTCEPe9qsYvOoMfnNkmxCHzsb8', 'name': 'Booking Details - 5. Booking Confirmation_car2.pdf', 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['1W_ZAY5ZUKu4mR3Y4T-4lHwYtnhOfk6Pb'], 'id': '1hIhDekCXNTwrM-2xaRoM-sbUTFagVl-d', 'name': 'Booking Details - 5. Booking Confirmation.pdf', 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['1W_ZAY5ZUKu4mR3Y4T-4lHwYtnhOfk6Pb'], 'id': '18lXx0mkSm7t5_Tef-bCH5F0VgAdk7QNU', 'name': 'AriTulla.pdf', 'trashed': False}
# {'mimeType': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'parents': ['12cj81Zqs4cSmX3U3yppirfUOo182m-Hx'], 'id': '1Wu0USCAp7C5Lo7wa3v7_iRGtJM4NxJbf', 'name': 'For participants: California study trip 3.-18.12..docx', 'trashed': False}
# {'mimeType': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'parents': ['12cj81Zqs4cSmX3U3yppirfUOo182m-Hx'], 'id': '1MzUq5dZMY9glV14Bi8ab2dla4I85Bdkj', 'name': 'Email/message templates.docx', 'trashed': False}
# {'mimeType': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'parents': ['12cj81Zqs4cSmX3U3yppirfUOo182m-Hx'], 'id': '1eBhjgaH31n74F4ozPbuT4iJNBsOh2fPg', 'name': 'Osallistujille_ Kalifornian opintomatka 3.-17.8. (1).docx', 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['1vlhGFI05GJUcuPp-9Rri7sx8wOD3z-MJ'], 'id': '120d4htTon5qv7gd0FjlMYaBnGUO1ipj8', 'name': 'Aaltoes California Application.pdf', 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['1ow8XsHp4k5ZzFYkMS4G45RgdI008j1z2'], 'id': '1zzDbQhUATZVga0KxMES87lmy9ktcjUUO', 'name': 'aaltoes-info.pdf', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['12cj81Zqs4cSmX3U3yppirfUOo182m-Hx'], 'id': '1HXgiiOYeNGQkMX1t7EsJtuv3VnvIYWbgSbQCf42mCec', 'name': 'Application draft:', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['12cj81Zqs4cSmX3U3yppirfUOo182m-Hx'], 'id': '1w0UwAA1x4TYs5MolhQPIXLOI-_Uf3kW28PieaHsDncw', 'name': "Meeting 9.9. (California'21)", 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1CDb9qWXpkH4ykRb752mJ650k0WI0T6wi'], 'id': '1jnhXVxMTuIseEA9fxN6GYb6UnLnP-4C8lYV5pEMiV3E', 'name': 'Singapore notes', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1CDb9qWXpkH4ykRb752mJ650k0WI0T6wi'], 'id': '1YwBq6sWiYJk2U8Y09UXOhFUHBGBtyTDJP2daUXJCHk8', 'name': 'Japan notes', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['1914J1MN8USaPb0Lci7Qt7bIkaxqXcFb3'], 'id': '13p8rs1Dnd7b2dOv2QRwjTpl2yOmfaj9RduSCH73EVyo', 'name': 'Zurich & Paris', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1U33okRj8P-e4U77LRY-dMrKV97dE0bWY'], 'id': '13P7-KaqFmXwKKB3BOk4ot7uRJs-5ULQQ4TWHqO6qaJA', 'name': 'Trip Practicalities', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1H7HRIXYQe7boo5r5BHLRzNpREkwH0wwU'], 'id': '1lht9EWYixm03Dymj-o7Wh38L8c4M1RamoHMZSRa6HZc', 'name': 'Social media', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1H7HRIXYQe7boo5r5BHLRzNpREkwH0wwU'], 'id': '1CIZQT_yau3Ih8SS4eUQH5G9ZXhpkzp8N6ye2Lqteroc', 'name': 'Application & message', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1WL0g6ULCKwqZIq7NDYIYmHiNnpJ7Lyh1'], 'id': '1fyzfsKZZ7ICIlGWr8Hvh6DfKnofV32P4gkhNg3oPgn8', 'name': 'Zurich & Paris documentations', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1WL0g6ULCKwqZIq7NDYIYmHiNnpJ7Lyh1'], 'id': '1gKm7fWBP-ycfymi4eqHXvzSJTkq2hAhfiJg8F4zOM_k', 'name': 'Amsterdam & Copenhagen documentations', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1WL0g6ULCKwqZIq7NDYIYmHiNnpJ7Lyh1'], 'id': '1gdelFw3-vSUQgfTGQW4l1GuWYhTrJbvRCXsNhqHC9Pk', 'name': 'Germany documentations', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['1jgvV7sB6EVzSHmuzY4FToaWAB1-aoc6I'], 'id': '1mfcl3pGmvoJ8lvE8JRxNihtQDEFN3trpPW5MfaCwb9w', 'name': 'Possible visits Amsterdam', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['1jgvV7sB6EVzSHmuzY4FToaWAB1-aoc6I'], 'id': '1tITcLD1QZDtB4_MVfdBKo-Bc0o30W2QdJ6_LgOyW9tg', 'name': 'Possible visits Copenhagen', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1jgvV7sB6EVzSHmuzY4FToaWAB1-aoc6I'], 'id': '1ynecbbWHLaLrMgA0wTOWq1aus62Trnxdg4PDGugPQM8', 'name': 'Telegram messages', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['1jgvV7sB6EVzSHmuzY4FToaWAB1-aoc6I'], 'id': '1h4tbdNuBfxQj_7MIioLzT_yoYJcVVtEZAVvUVkjb7MQ', 'name': 'Amsterdam & Copenhagen schedule', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['1jgvV7sB6EVzSHmuzY4FToaWAB1-aoc6I'], 'id': '17igQg-G90Vqz2PBIDW9K9Bp40st8DTOpjpmH0sGjnBs', 'name': 'Amsterdam & Copenhagen budget', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['1H7HRIXYQe7boo5r5BHLRzNpREkwH0wwU'], 'id': '1qxuq4Ym6g4vUq6gqGQ56NB7_9L2vgnV93sFrgPFfIXw', 'name': 'Europe trip applicants', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['1H7HRIXYQe7boo5r5BHLRzNpREkwH0wwU'], 'id': '15mPsI5MYr0dEtt9I-YqtQhUAF9DBAzLbC_qJ5xJT95Q', 'name': 'Europe trips', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1H7HRIXYQe7boo5r5BHLRzNpREkwH0wwU'], 'id': '1aOqSQOP2isivnnRKgLDSaGCpiFXAjqtPLHX0phjXojc', 'name': 'Coldmails', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1teOblFmvmeQxKl1LAYd-p3t24jfGnNZy'], 'id': '1selkd89-c-BkhNBkPaTNejkGkMXB44I1Nc8FLIuKxT8', 'name': 'Untitled document', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['15hSlZp-4v3RSI_P5QWcdlTfeibofLlFi'], 'id': '1ZwF0bHXDvqm2CYAEBaYvxd_UjCplRTwxX-UBs8WvtzU', 'name': "What is Aaltoes '21", 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1diThzizRmApL2BIUE10ichWzk76kCeWK'], 'id': '16rUYF4yazwKRTW6mjypO7vElV2bVQmH1-cba0jb2wu8', 'name': 'Meeting w/ IITB 18.10.', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1diThzizRmApL2BIUE10ichWzk76kCeWK'], 'id': '1n2o6uF5EbmuoSmBmA97_rgQrXcpOpNJVJoU1ijU5jpU', 'name': 'Meet w/ Ilja 11.10.', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1diThzizRmApL2BIUE10ichWzk76kCeWK'], 'id': '1RCbY0AkukYT9SVeH9myYvMMWu7bgG3JhRXsN7YCzLXY', 'name': 'Miitit 20.1. refined', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1diThzizRmApL2BIUE10ichWzk76kCeWK'], 'id': '1Mp_3uVj1ECojxeD1wH3gEys0rViNrAG4X63AZVXWmfE', 'name': 'Miitti Iljan kanssa 20.1.', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1diThzizRmApL2BIUE10ichWzk76kCeWK'], 'id': '1FANHzGNly78puZ4Bl-YbD3lyjN3dcfo01Jtv0zv15gg', 'name': 'Start Summit', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1ySYC20BwigYcZmBBXr12qWaoi5gwOXrf'], 'id': '1smJV3_NDsaqdRvkJ_QKPSqD-BAiM6RkFyQJZ24c7nw4', 'name': "Alliance 1st meeting of '21", 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1ySYC20BwigYcZmBBXr12qWaoi5gwOXrf'], 'id': '1YucMwC8J1TcgZuNL-_ZQnrdNmE6FhAM9xMl0VxYezyg', 'name': 'Notes for Alliance meeting 4.2.21', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1diThzizRmApL2BIUE10ichWzk76kCeWK'], 'id': '1rITcU0asdC3qOoNhgiqQYMbvGUSx0MwquERavSdsupA', 'name': 'Copy of JunctionX Seoul x Aaltoes meeting 29', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['15hSlZp-4v3RSI_P5QWcdlTfeibofLlFi'], 'id': '1avRNdO8mgOTATJDd23V6HEkzhiIYvmeLOdcD73rf9Jg', 'name': 'Copy of Copy of Tyhjä presentaatiopohja, kopioi tämä ja kopioi/poista slidejä joita haluut käyttää', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1yZeAbVbHcoP24mN1CIb0Lv0SGboM6aOM'], 'id': '1WTMEW7ycHwsLDhN8KMBPVKmnKnT2SfDtUl4-xC__r14', 'name': 'Aleksi, where we are going @Q2', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1yZeAbVbHcoP24mN1CIb0Lv0SGboM6aOM'], 'id': '1fC5LqxXgdTu9AnBSGoDAPICQuwujc5Wbea7xDsdqT_Y', 'name': 'International Relations - Status Quo & Strategy', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1yZeAbVbHcoP24mN1CIb0Lv0SGboM6aOM'], 'id': '1lZTsD-tFr7vzxsTTKzBm-eH6Y24GwwJU-TFdNTig9fo', 'name': 'SILTA rahoituskysymykset', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['1yZeAbVbHcoP24mN1CIb0Lv0SGboM6aOM'], 'id': '1Qa8pUP6Cp23p7u53ruBjvFxeoD02b0MMeuMtCBOaK3k', 'name': 'Contact list', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1yZeAbVbHcoP24mN1CIb0Lv0SGboM6aOM'], 'id': '1AAiiAL0j2L3_4ikKc5nRWp6SwE3U4AKpMaCqSVSLPd8', 'name': 'Copy of Aaltoes', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1yZeAbVbHcoP24mN1CIb0Lv0SGboM6aOM'], 'id': '17N6B9KWI7tqK5kL1ux_4tBaqwwg-KfyxQFGn8sX4ojQ', 'name': 'Ideas/opportunities', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1yZeAbVbHcoP24mN1CIb0Lv0SGboM6aOM'], 'id': '11B_gyzi0P3k8Fu6md4MxqWsbmf2RxLIm5KMvg0dGJJc', 'name': 'Tapahtumia', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1yZeAbVbHcoP24mN1CIb0Lv0SGboM6aOM'], 'id': '1bu1TfCm6DScWT447cL9L9ySexYJwZRtqIgZPp_m3p2k', 'name': 'Linkkipankki', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1yZeAbVbHcoP24mN1CIb0Lv0SGboM6aOM'], 'id': '1_iDRcg8LOqIm5Fa5vBn-0yUNNAdFpuWIaazwQ_FeCDk', 'name': "Testamentti '20", 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['0ADODK3buTEqsUk9PVA'], 'id': '1pn3Ioi98XtRzSln76niLABim0M42pPDI_Ck9WQV3yFU', 'name': 'Untitled document', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1o1oShKJ5On1eAqgeF-pLzk_SZWUnazO8'], 'id': '1Thpb79ajpxrHSvV3n9f4xyrGDDBaexWgHkClCDf5IZg', 'name': 'Early Aaltoes Deck', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1o1oShKJ5On1eAqgeF-pLzk_SZWUnazO8'], 'id': '11Q7quQzgMronV5oHPLpkksPAmoyVyUkjcsYgI_U17nU', 'name': 'Aaltoes Deck', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['1Fo5jcjr99b75A46Th92ijccos5Xs_QBw'], 'id': '1LZ9tJSuL6oO3K2uC43AS3Q238lLoOGECRK2YO6aMHDo', 'name': 'QR codes', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1Fo5jcjr99b75A46Th92ijccos5Xs_QBw'], 'id': '13NubRFwhuwjBCC6N5loCqwP3hZCe-_4s5l3FIi0K5bg', 'name': 'Tools for Marketing & Design', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['1Fo5jcjr99b75A46Th92ijccos5Xs_QBw'], 'id': '1eGgRkfHs1EnWl6LWL75I1JhQlAP0DQREQqA4F8iuapE', 'name': 'Channels for marketing', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1g_I634kPBpqcbnZJ90-dl8zV_M47Ooy_'], 'id': '1exWyGr9tvaDAs6QqmqeKlC0PHythpaCGB6wRD5ey8b4', 'name': 'Responsibilities', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1g_I634kPBpqcbnZJ90-dl8zV_M47Ooy_'], 'id': '1hoTDXwXZophJrgTQjCRhbevXh_9LtYHQBQCMESOw_00', 'name': 'Marketing & Design Reflection', 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['1g_I634kPBpqcbnZJ90-dl8zV_M47Ooy_'], 'id': '1KGMKVW-QQ06z5xqrcsJHAkqz1-Mzs9GT', 'name': '6 MONTH CHECK', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1_7ty5FenJR6wtg3KISvpBCwYUdHYmhNF'], 'id': '1J3hVQZC8hWpzKkEEKv-BGbX0TOMMkVojeAZLF1YLmZk', 'name': 'Sisäinen viestintä', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1Zqzu98IlPg9m9I3PXBU20UQUp6OgRSQP'], 'id': '1XVMj03M2PnNvRWBdUJ1GeHy59FLnohaSxzaxdVlTZPU', 'name': 'Merch', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1Zqzu98IlPg9m9I3PXBU20UQUp6OgRSQP'], 'id': '1K8rIqyEDY1TykdwA_Ja_WYQh3V2AxMqOM8NLv4nOwLU', 'name': 'Merch "inventaario"', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['1XWNnn9J0FCZRtv3gxt4i3DVrjGuWKvbA'], 'id': '1cnClhX7KVghk_SaBK7GXMwR0AWkueKj6tria8ELiifM', 'name': 'Aaltoes alumni companies for website', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1KOc-JMzrJWb4V2D4FK4lm_mcb2Rj0ICj'], 'id': '1vrxRuSTAsmFvF0cGYrWfpnShEwXgE8QWsMzwcH_LiTY', 'name': 'General texts about Aaltoes', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1KOc-JMzrJWb4V2D4FK4lm_mcb2Rj0ICj'], 'id': '1EXN4fF9n5RFkckiHsuq-GvSW7wGXi7tGiQa8SAFY1A4', 'name': 'IG POSTS', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1KOc-JMzrJWb4V2D4FK4lm_mcb2Rj0ICj'], 'id': '1E-QAJ1raX_BOZHoqReDux04sueYUVwe5tqDcD37Hhgg', 'name': 'RANDOM MESSAGES', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1KOc-JMzrJWb4V2D4FK4lm_mcb2Rj0ICj'], 'id': '1hcPzkQG8Vp93BRJLakB94ZaGZQOiIaFFiLwhRxyqK-g', 'name': 'WIKIPEDIA', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1QGLVHsluSA1CB7UtZnoumymmrujNffRw'], 'id': '1jrXFQ-HxVc1eUSB3_k-xCGapcwh3qJt6KdoPpiJ4S2Y', 'name': 'Book Club Marketing Texts', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1QGLVHsluSA1CB7UtZnoumymmrujNffRw'], 'id': '11poPgA0k5izKos-M-_F2l6OygVZHyk83bRpo9KCrM6U', 'name': 'Book Club Registration', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1j22JkJpsyI7mrx75U5wSOhSv5aY-3qud'], 'id': '1PE7ns9skVH1020SgjQYe-A2DSOVI5rSmhCrE0sbPzzk', 'name': '2. DONE – Erwin Laiho: Prototyping your idea', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['1j22JkJpsyI7mrx75U5wSOhSv5aY-3qud'], 'id': '1rvzamD4pD7RgZ7mdy9OPSnqXdEIb9aweFXK1SHSQnM0', 'name': '1. ILMOITTAUTUNEET + TOIVEET', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1j22JkJpsyI7mrx75U5wSOhSv5aY-3qud'], 'id': '1wl6sSnkcTqUdYeFBUtumapg9ysNbx8ZuYwJRUtG18EQ', 'name': '11. DONE – Inventure', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1j22JkJpsyI7mrx75U5wSOhSv5aY-3qud'], 'id': '1FuHBJZfKCqXEli0Epp0PBFIxkso0zAYBZ-JAYR5KVbA', 'name': '1. EMAILS', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1j22JkJpsyI7mrx75U5wSOhSv5aY-3qud'], 'id': '1BS497YzXcc7kRkoYvO6xIfLd3ZHNT9oOfWorhwa1U5Y', 'name': '10. DONE – How do VCs operate? With Thomas Bacon and Petra  Koivuvaara from Maki.vc', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1j22JkJpsyI7mrx75U5wSOhSv5aY-3qud'], 'id': '1PByq8YZyQncKSaRyi7SWgsHXtYzM_Ey24c7s14tdgSo', 'name': '7. DONE – Designing your business idea to executing ideas in practice', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1j22JkJpsyI7mrx75U5wSOhSv5aY-3qud'], 'id': '1JQyxK1vEpqZwDOSldATN1dqJgSn19Lz70z8p0fgYCRU', 'name': '6. DONE – Impact  Entrepreneurship', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1j22JkJpsyI7mrx75U5wSOhSv5aY-3qud'], 'id': '1buQN-gkxO0xVYru4dChjAbZz9h8mHB0ycLkCOoIp5EU', 'name': '9. Q&A with Aaltoes founder Kristo Ovaska', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1j22JkJpsyI7mrx75U5wSOhSv5aY-3qud'], 'id': '1SneVL45Ex7vzIEimr5Ntjq7hbWUo0m_8uRSHh4x3GV0', 'name': '5. DONE – AIC x Aaltoes: Introduction to Venture Capital with Oona Poropudas and Johannes Tervo', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1j22JkJpsyI7mrx75U5wSOhSv5aY-3qud'], 'id': '1WRem1su9mlvk0EGIS5Uv9dGQPSbhx8gVdV_3w4Q3-n0', 'name': '4. DONE – Ilmi Salminen: Designing your life', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1j22JkJpsyI7mrx75U5wSOhSv5aY-3qud'], 'id': '1iDm0cYsBRcq0HTGrvvtFvXySYzTo5L6D0iIUjFqXUJg', 'name': '3. DONE – Axel Cedercreutz: Founding, starting and leading a new project', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1j22JkJpsyI7mrx75U5wSOhSv5aY-3qud'], 'id': '1WLP82BYB2whqxv8s61qbPcmobWftYwNPqlufNMcKz_M', 'name': '2. DONE – Meeri Moilanen: From Aalto School of Economics to the London startup scene', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1TsCEkNW2lz0JwvGY3mxlXjK1txjU_lqe'], 'id': '1UL67btpSW1ZaWoGtiL1S2FV6_znmb9B3oEzxfTHOQaQ', 'name': 'Playbook draft', 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['1TsCEkNW2lz0JwvGY3mxlXjK1txjU_lqe'], 'id': '1QutwYsIJjb5gsi9qshWMSyqbUZa7m5tA', 'name': 'aaltoes-playbook.pdf', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1HLkL7drkz4eGi4mlmZZGjmSpJchry-Pi'], 'id': '1KfLIYmVzuSxuIrCHq0r2y6_s8hcbPmRSipzglSar4Y0', 'name': 'NEWSLETTER', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1HLkL7drkz4eGi4mlmZZGjmSpJchry-Pi'], 'id': '1CvyXO85BCPriWeir_N8dgrMs3O62K1vuYx_xG0Xcvdo', 'name': 'EUROPE TRIP DOCUMENTATIONS', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1HLkL7drkz4eGi4mlmZZGjmSpJchry-Pi'], 'id': '1XrBuKAP_rkz5yJyUAU2lNojBAs2KyEapQqodLWPEm20', 'name': 'CALI TRIP DOCUMENTATIONS', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1XXGRn-1SVE6eeNbZSLQS7z1qtb5IxQNl'], 'id': '1KGVzo1R-pw6h-fMHrdC48Itp2vdriBKKMxfC8hY9ER8', 'name': 'MONTH RECAP REELS', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1HLkL7drkz4eGi4mlmZZGjmSpJchry-Pi'], 'id': '1a2ysSIE6tC-Kmup_UqlYtGh23YGIKey4KgVj-h3JbXY', 'name': 'Q2', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1HLkL7drkz4eGi4mlmZZGjmSpJchry-Pi'], 'id': '1fihACQ2qwl4yCseNPMci0mGyfQbtpR7K5256vwDGT9Y', 'name': 'Q1', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1web-j2QMajkoIO0T40mKXz2sc3ikSNml'], 'id': '1ItbHr5a5ssY2BIk0igxBKD-I49Ood4mOByppZ-t6IQ8', 'name': 'SLUSH ICE CREAM BAR', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1web-j2QMajkoIO0T40mKXz2sc3ikSNml'], 'id': '1AjRthyQxYIbZ0zrLDoSzerg7H0__fWXOUWdON-DDKeM', 'name': 'BENJI', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1web-j2QMajkoIO0T40mKXz2sc3ikSNml'], 'id': '1s_qtMwBjwZ-wi_Iv28ieI5_OZ8u4coCNvHbkM-6ScrI', 'name': 'SLUSH AALTO BOOTH x AALTOES', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1web-j2QMajkoIO0T40mKXz2sc3ikSNml'], 'id': '1B3EwbCZHKXWGu2ZXHsNxveq9Wc1O_v-Gv9R2es2MMy4', 'name': '1. ORIENTATION TO DO', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1web-j2QMajkoIO0T40mKXz2sc3ikSNml'], 'id': '1TD8OyuMJopMfEro8ReN_PImZCCRakDJtqVu_jfG-fgI', 'name': 'OTASUUNNISTUS', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1web-j2QMajkoIO0T40mKXz2sc3ikSNml'], 'id': '1idEHrUXKvhc2xGqYMfJH03DBT8n4DHATpG3ppPkj-LI', 'name': 'BOARD INFO-EVENING', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1web-j2QMajkoIO0T40mKXz2sc3ikSNml'], 'id': '1qviTR8SF5mWSpeoodvqxJtingkMR5U3UKt7GHBeZSNc', 'name': 'SOME DURING ORIENTATION', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['1web-j2QMajkoIO0T40mKXz2sc3ikSNml'], 'id': '1f78ISe5i5JnWOjgPemJmi4j4lmjy0kIm5DzPi9wDDJ0', 'name': 'Explore Aaltoes participants', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1web-j2QMajkoIO0T40mKXz2sc3ikSNml'], 'id': '1bncDxYf_MhDc7ATCSXM21bhw-PCCHHBEwyvI9e8Bc08', 'name': 'VAPPU MARKETING', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1web-j2QMajkoIO0T40mKXz2sc3ikSNml'], 'id': '1a9kTJSAE-Qac868QmW-GvmvNJfIJJmZg5oGwwVxzqDk', 'name': 'MURSUMESSUT', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1web-j2QMajkoIO0T40mKXz2sc3ikSNml'], 'id': '1-5PCjZI2H9DmkGD59w8Ffd4opMGTVmzBjUxU-7OMDX4', 'name': 'EIT ORIENTATION Q&A', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1web-j2QMajkoIO0T40mKXz2sc3ikSNml'], 'id': '17XhHPzPJWLh8zPsJ2X-0zyO0j5HyA5JVjtn8JpVLrKs', 'name': 'FUKSIT', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1X3LwSdVmd9KHBfEsDLTYt6K-Oec6Ee84'], 'id': '1oNaiFnmWKqO8qGGf6I2rpbjUQegtqBuGV3FQn2ADboo', 'name': 'HS Visio artikkeli', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1X3LwSdVmd9KHBfEsDLTYt6K-Oec6Ee84'], 'id': '1-aY6jrhdmWaKqAGDweqTSGzTqB0l0RY50GlPj0L8d9I', 'name': 'Media notes', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1X3LwSdVmd9KHBfEsDLTYt6K-Oec6Ee84'], 'id': '1gDuaM3yFEGeiCLy0AuabRcNrprIcG38NNz1a8dQwGCM', 'name': 'De Barometer TV show', 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['1IoQZvN3JfqCRPnhTQku5UK7xWWZoTuMQ'], 'id': '18fMQJhyN1du8vx-VJYM5plkE5rdP-Hqt', 'name': 'Aaltoes-Brandbook.pdf', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1uMUk8PCaJuAxSiSUIdjmyRTai662iS-N'], 'id': '1psgIIbhOJerF_kUKvZccVSphZnSJN72Y0LSbe7jZUVE', 'name': 'Brand brainstorming', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['1I3WRut9pe0GC9YuacNF2nI9d2Vvun6JJ'], 'id': '1xJqAMkp9iMWVVfoMcMnWfsgHp6Uf1msPFjY2MFlJrvM', 'name': 'Aaltoes Data History', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1I3WRut9pe0GC9YuacNF2nI9d2Vvun6JJ'], 'id': '1FLQOZaLIRWuMR8ZJMQXPO1RNXugsMKD6RuFf5ZAsqqY', 'name': 'Markkinointi – Survey on Entrepreneurial mindset and Entrepreneurship ', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1I3WRut9pe0GC9YuacNF2nI9d2Vvun6JJ'], 'id': '13CjGIl26vL1bMbRMttT-hUsq0U90Y-O_PDLFXWUjsPU', 'name': 'Survey structure', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1I3WRut9pe0GC9YuacNF2nI9d2Vvun6JJ'], 'id': '1E0PQ32MEc5Alcgdt20_zXD9US8XThnrJrhdfS1tmneA', 'name': 'Datankeruusuunnitelma', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1yMRvcmDMGtxCHSz6_8qjwJcXab2C1_zI'], 'id': '1ZFghAUyL8k5BSOkqp4157_GnaNZbQm7ZKHQV7PeAIDQ', 'name': 'Oscar Björklund 9.3.', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1yMRvcmDMGtxCHSz6_8qjwJcXab2C1_zI'], 'id': '1eMWTpV-S7FY5rs-G6em7vC_0m_8AeHyTnA8CnOnMVPM', 'name': 'Jouni Lounasmaa 04.03.', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['1MauFD0NeFYQGdq5IAGDu10r_k0n-HXlb'], 'id': '1HPOC3oNebjj33bASq0FY-MezdTXdxlqsiR9scfT70DU', 'name': 'Registrations', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1FdRTvrlQdTGs6eoFdqoMh7hVZ52yTEgA'], 'id': '1FcAApxuF4JvAhG5x0XTQaC10ZxvxXC4D87b0K5TBDb0', 'name': 'Purku', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1Yc8ZaxZyL6xJ0X2XVAh7gM-pmE6blZko'], 'id': '1TOGURunAiXUX6XOZ41oQrDyHvmttq8Kweq9vQYCwQh8', 'name': 'Tyhjä presentaatiopohja :-)', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1Yc8ZaxZyL6xJ0X2XVAh7gM-pmE6blZko'], 'id': '1kELZiLh2DTCugluFtz3_rPT1xODuGLbHFu3khaIppBQ', 'name': 'Series 4 ', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1Yc8ZaxZyL6xJ0X2XVAh7gM-pmE6blZko'], 'id': '1_MMtz7U9T2NNLjdPCHtiwA5WaRx2Zi72Szzwuz3dTMc', 'name': 'Series 4 Plan', 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['1TD_ws9EmphAeIKSlfY_WKTDCTchEvAJC'], 'id': '1klkkvrOw0O5drvUmVKSXbOpRE1GVUG6s', 'name': 'Series 4 Budget.pdf', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['1TD_ws9EmphAeIKSlfY_WKTDCTchEvAJC'], 'id': '1r-XlCPkXp6e-6FD_L6i5htzmGh7lTZu9WtDmDMchvFU', 'name': 'Series 4 Budget', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1Yc8ZaxZyL6xJ0X2XVAh7gM-pmE6blZko'], 'id': '1JM85K_cR0rNjY9jz3OcXGGz3jrAtSjJHwbeTcnHuEtY', 'name': 'series4', 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['1Yc8ZaxZyL6xJ0X2XVAh7gM-pmE6blZko'], 'id': '1jzLGPvTNpIeBVvp5QObdrlR-62hE6wUo', 'name': 'series4.pdf', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1Yc8ZaxZyL6xJ0X2XVAh7gM-pmE6blZko'], 'id': '1tnaXkyad60lYo9RHqxrAdd5TcNzCPHhQKE6UCA9i72U', 'name': 'Copy of Series 4 §', 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['1Yc8ZaxZyL6xJ0X2XVAh7gM-pmE6blZko'], 'id': '1lPvF6isx698-EOkA6h1qokwZjEb-FPEb', 'name': 'Series 4 Pitch Deck.pdf', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1Yc8ZaxZyL6xJ0X2XVAh7gM-pmE6blZko'], 'id': '17NC69TbmaOt75qUyJIj7NhwHhMIyxX_jeKeKHpobXLA', 'name': 'Petruksen pointteja', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1ZC9qUMrw_DLskCTxecmq4neHodNPC-Fy'], 'id': '1HR5WaoZJd07aRx_eiji6CeFydRC7vZHpACO-S6eu9UQ', 'name': 'Aaltoes | Deck', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['1ZC9qUMrw_DLskCTxecmq4neHodNPC-Fy'], 'id': '1a352oYBacsCZMSkWOxvf5qF2UK07GIrSGpiDc0YmMlw', 'name': 'Aaltoes x LEINN participants', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1ZC9qUMrw_DLskCTxecmq4neHodNPC-Fy'], 'id': '1nQVolQLlOuVw-TOrTEz9j_Bv--5D65a4hqd53GPVZ2c', 'name': 'Aaltoes x LEINN', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['10U9SBBlc_SRbtF6-MyYr6g02vNJHaH8M'], 'id': '1XYJkDNUJwpVukhojPi0L-wYbceE8ds8VmFBCYeSXwzM', 'name': 'Purku', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1S3sj7HZwPMDxUpYsT2kcoFLCvsbE7KJV'], 'id': '1SswCD0VwEVHBdk-dWvNIVjIhVvxmFERZhQMvBWojLNc', 'name': 'Operaatiot', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['12Na_lv9R9HJS2ujwzPia6DaFuKl0XC9J'], 'id': '1zKU2Jmso_w4piMxKlzIbEb5a4nU_FDsYO0Tw2fxmJiI', 'name': 'Founders Club participants & wishes', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['12Na_lv9R9HJS2ujwzPia6DaFuKl0XC9J'], 'id': '1Jrf7RNHfDe9q0C_1_vfyE8Qh29DOKnSLdOR9qiVeDz8', 'name': 'Founders Club', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['12Na_lv9R9HJS2ujwzPia6DaFuKl0XC9J'], 'id': '1cbsgrwKF0NJ8PXY2lKHe21X6tWLr6x13Lso0vvxOCGo', 'name': 'Founders Club Calendar link', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['1Nvfob4O4vsB2NWoYxUxg-EJ8Ly2nVabz'], 'id': '1uXs_GROW1a5_OoPtlTXkPJLYikrWnMSzwLCw2ZZZmVk', 'name': 'Macau VC x Aaltoes', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['1Nvfob4O4vsB2NWoYxUxg-EJ8Ly2nVabz'], 'id': '1nMZAw6xzW6Xh77UvnwNkQ27KO2U8bD4nFFYrCf7oCCA', 'name': 'Through customer discovery to product-market fit:  Riku Lindholm, founder, Meru Health (YC) ', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['1Nvfob4O4vsB2NWoYxUxg-EJ8Ly2nVabz'], 'id': '15C8Miyk1JMIQ-P95H5Rqlte0lVa4RJL6Lwy7sfnFf3w', 'name': 'Startuplifers: Recruiting', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1Nvfob4O4vsB2NWoYxUxg-EJ8Ly2nVabz'], 'id': '1yfuiDa_F5B_f9-gTfALb-a03J8ABqpX7_C7AQW1XXqc', 'name': 'Founderxmas Party', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1Nvfob4O4vsB2NWoYxUxg-EJ8Ly2nVabz'], 'id': '1JRq5tg02OzIZvMsc9s_dARjM2qBE34je6bgCyM44_5c', 'name': 'Founders Club meet-ups ', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['1Nvfob4O4vsB2NWoYxUxg-EJ8Ly2nVabz'], 'id': '1EdjurYQUWKyQRLvZs6SGyLTxqyEqxDZ_fXaoAO9XBx0', 'name': 'Sales with Mike - Founders Club', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['1Nvfob4O4vsB2NWoYxUxg-EJ8Ly2nVabz'], 'id': '1SxKX04CX1vtxQfIi_PdRCFjZTFHz1gfP61GjbnpnDY0', 'name': 'TK-Ventures: The first steps of a startup', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['1Nvfob4O4vsB2NWoYxUxg-EJ8Ly2nVabz'], 'id': '1_ep828T22hwLimYtm5OQxrVdPC9ZeTi_1IidGMGh4mQ', 'name': 'Legal 101: Sebastian Vuoritsalo, Dottir law', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1Nvfob4O4vsB2NWoYxUxg-EJ8Ly2nVabz'], 'id': '1gXDO-A__gRBstWiRiq7rirxewM3I4MRZwrdGpaATbQ0', 'name': 'TK-ventures events - message', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['1Nvfob4O4vsB2NWoYxUxg-EJ8Ly2nVabz'], 'id': '19KpsZGNPJbj1S6ysrxsT68hxq5NQn8g-8l_can9mwm8', 'name': 'Business Game - Founders Club', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['12Na_lv9R9HJS2ujwzPia6DaFuKl0XC9J'], 'id': '1ZSUg7ZwzfwYJfBKhJklwJNp4hZnbktTfr39e9lZkLGc', 'name': 'Approved to Founders Club Message', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['12Na_lv9R9HJS2ujwzPia6DaFuKl0XC9J'], 'id': '1BCQXLeuPO64qrQzpR7BAs7sjGYQPPYQUnXlGvhE-qQw', 'name': 'Rejected from Founders Club message', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['12Na_lv9R9HJS2ujwzPia6DaFuKl0XC9J'], 'id': '1Tzs0xZfB7BgrXGPC2BAQsdTHyfWe1Kz8nrEOmAi7WCg', 'name': '1st Meet-up ', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['12Na_lv9R9HJS2ujwzPia6DaFuKl0XC9J'], 'id': '164tslt4M0HwDPmpSDsvAyQY50DA9VGu6j_7_1CnoQSY', 'name': 'Thanks message of the launch & invitation to Slack group', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['12Na_lv9R9HJS2ujwzPia6DaFuKl0XC9J'], 'id': '1PY4AAvT0IBPVOg5fhiKQ6L4D1mlMNX4S4RznuR5cTDk', 'name': 'Speed dating questions', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['12Na_lv9R9HJS2ujwzPia6DaFuKl0XC9J'], 'id': '1h91ViXzXpL4IPQYsfaGgp3ZK1WTO3fJF1VLnHTobXag', 'name': 'Founders Club Launch - 31.8.2021', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['12Na_lv9R9HJS2ujwzPia6DaFuKl0XC9J'], 'id': '1FknFgtAA2W08VMywHifM9kKAsuNczNi_rHWf4DlZxcA', 'name': 'Launch Reminder Email', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1Mtgivh0oXs5VsN5qiPyBwtV2SfFd0MIJ'], 'id': '1etYwxz5UB0mJql1Zs5w2idhjL4aJ55S3YLHJwdoqtm0', 'name': 'Kysymykset ja rakenne, Helsinki', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1Mtgivh0oXs5VsN5qiPyBwtV2SfFd0MIJ'], 'id': '1jkE7cBUPEYTPprRWViCQQVlW7XsRz7tvzQGrNJ-prhg', 'name': 'Vaalilöylyt markkinointi', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['1Mtgivh0oXs5VsN5qiPyBwtV2SfFd0MIJ'], 'id': '18imf1dvMUCOlmJ3MSaHiM1E61QHJ0f1QiRP6r-u-6HE', 'name': 'Panelistit', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['1Mtgivh0oXs5VsN5qiPyBwtV2SfFd0MIJ'], 'id': '1C8bdNq_urjZsxomjhn7ZvGYATILeFEGrMc1ek8OrQ98', 'name': 'Vaalilöylyt ilmoittautuneet', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1Mtgivh0oXs5VsN5qiPyBwtV2SfFd0MIJ'], 'id': '1nCxIgSsXrUtpiD1NtnMF2zbYoZVmpAmKrashUkIAIYY', 'name': 'Vaalilöylyt: Ohjeet ja ohjelma', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1Mtgivh0oXs5VsN5qiPyBwtV2SfFd0MIJ'], 'id': '162awTHOrb5t4lFsUq9AzAv2gxNPAeSCtuDemWHy60lU', 'name': 'Kiitosviesti', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1Mtgivh0oXs5VsN5qiPyBwtV2SfFd0MIJ'], 'id': '14pTyPBQHaNOl4dhr0mJhjC9D_Tod6-mmJ6x7wP8Nflw', 'name': 'Kysymykset ja rakenne, Espoo', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1Mtgivh0oXs5VsN5qiPyBwtV2SfFd0MIJ'], 'id': '1q1DbGhP4SLlTS9MNh7mUGgkrcydLGImcpce9ILFszXM', 'name': 'Vaalilöyly: Notes', 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['13neOiTXld59mSdtshoCmB02eyegZuEII'], 'id': '1G8hTFtoKzfEAN-RzoilDwZSuzmi3Jl3m', 'name': 'Partnership contract for Ignite 2021 - EMU (1).pdf', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1p_-j6S4CpFstYX4ckCf46XHswf7W1WMf'], 'id': '1MynpA50MZNZt0r7ZK-mI_-jt-U_3q5PmFkNeAK-Q8JM', 'name': 'Case VTT', 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['1p_-j6S4CpFstYX4ckCf46XHswf7W1WMf'], 'id': '1lqvaWe4fGF24a60eBJDofhvZAoIwbWzr', 'name': 'vtt-aaltoes.pdf', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['1noTmiFHfV3JKdsaNAHEpYtRBA1QF5dQS'], 'id': '1uuEQzmg2hyDZkyW-IBRY1-Cwg1HoGeZjt2gejqtSQb8', 'name': '1. TIMELINE & IDEA BANK', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['1noTmiFHfV3JKdsaNAHEpYtRBA1QF5dQS'], 'id': '1A0jD57mqC4hROy8F3sVk9Wo5N1bVdmm2G2KAp6Cmyic', 'name': 'EEW Autumn 21', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1L_cL37q0tYvWt0G2hB7YsoXATKj-1SHM'], 'id': '1J4bKwaIN8K0CF-Mqh3CyzSf90352_wwUJiymsfjGPPk', 'name': 'Video Installation', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1L_cL37q0tYvWt0G2hB7YsoXATKj-1SHM'], 'id': '129YR2LR8-8mMYLBG9IAm9EaMZEn1-7pN9jAA2oG4HjA', 'name': 'Kantava idea', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1L_cL37q0tYvWt0G2hB7YsoXATKj-1SHM'], 'id': '1Aq7ZDwVzU84JgJVFcc93HYsq5v-UQgIhKYm74dlV748', 'name': 'Yrittäjyys lähemmäs opiskelijoita', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1vdwQRV5aTpoqJBBSulnD3IZwoAiEVh7Y'], 'id': '1SmZroJJzzzbY0uHw8UbHOt9J-oFE197dlT4BkY8mRzM', 'name': 'Lottery lunch ', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1vdwQRV5aTpoqJBBSulnD3IZwoAiEVh7Y'], 'id': '1BC5i89aniLdn_drAoZ6ZghTkEeUqjaBxkizpuR4u9AA', 'name': 'Mentoring program meet w/ Niko', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1xENkUBNv_t58_g0Um3S6oFRG9f-hZets'], 'id': '1g_VFN9bG9aPbTVpPxM3_Pag0X6qBw7pKDq68qTfdycA', 'name': 'Aaltoes ', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1xENkUBNv_t58_g0Um3S6oFRG9f-hZets'], 'id': '1vBxL69vSuOt8rRET4ngx-s-6HvZ8cWyJ8IovLFTx39k', 'name': 'Series| Deck', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1xENkUBNv_t58_g0Um3S6oFRG9f-hZets'], 'id': '1b9xhTdr6rd-5uYz9fCR0F-1i8pDdXNfMElMNluWrSzc', 'name': 'Copy of Aaltoes | Deck', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1xENkUBNv_t58_g0Um3S6oFRG9f-hZets'], 'id': '1QXYzi0QPhaD2lRFfrBgg4C40QYlyWwB-98CLW_ToRsg', 'name': 'Copy of Series| Deck', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1xENkUBNv_t58_g0Um3S6oFRG9f-hZets'], 'id': '1xkVO9kzQYcEcQ6SQPi50J80kqK6Xv7HEwqoEpuaJu-k', 'name': 'Thank you! ', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1xENkUBNv_t58_g0Um3S6oFRG9f-hZets'], 'id': '1FkbIRrd98JvbD4vbuhfooQ-Lhz1j2PDouzZE5lepKmM', 'name': 'Aaltoes', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1xENkUBNv_t58_g0Um3S6oFRG9f-hZets'], 'id': '15Ms0W5xWC23ixLIYyGhKQ69GaSz5GAkQRhhrkYx5l_U', 'name': 'Aaltoes| Aalto University', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1xENkUBNv_t58_g0Um3S6oFRG9f-hZets'], 'id': '18bqqYi00dg_M-GjG5DqnLAcX59mOJCO8jzK1sYfgddk', 'name': 'Aaltoes | HITP', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1xENkUBNv_t58_g0Um3S6oFRG9f-hZets'], 'id': '14ge-j-4GhjTeO06-VQqLnEmJ4DglpL-hObhHSPXBNR0', 'name': 'Aaltoes 2021 Pitch', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1xENkUBNv_t58_g0Um3S6oFRG9f-hZets'], 'id': '1g0eIz-mP-BnnAhywzZRsGuPKen4RsOhY8YXSYTK_Knk', 'name': 'Ignite', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1xENkUBNv_t58_g0Um3S6oFRG9f-hZets'], 'id': '1JDOO46thPsRcPXmMpeC2xS0rBq4TzyD2nU_NP1m94aE', 'name': 'Mökki', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1xENkUBNv_t58_g0Um3S6oFRG9f-hZets'], 'id': '1yRrC1wNd5RbTuSRQwBhqLqkBoqZzRG1i9nqHIKqQQdg', 'name': 'Aaltoes', 'trashed': False}
# {'mimeType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'parents': ['1s0Apvc1CDR_HY49VdtDfJPH_VbTHP9lQ'], 'id': '1H7Cg9GaFC2lQ42C3KaiNoUr5SUNJqJL3', 'name': 'Tilikartta 2022.xlsx', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['1s0Apvc1CDR_HY49VdtDfJPH_VbTHP9lQ'], 'id': '1ygV73MS_wryRsBAsDaAGfsZVHwtBa6WShf91pEjn8eY', 'name': 'Puuttuvat kuitit 2022', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['16IdYyBy-oKmFycaBJCt6hAsF20EOT-LW'], 'id': '1QxXEvAnAzSZ47RChxM0LHhutvYp5B0HARB_lRT5K_Zs', 'name': 'Tammikuu to-do-list', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['16IdYyBy-oKmFycaBJCt6hAsF20EOT-LW'], 'id': '10iNc9OulWD-nmsdVL_qmyEObJA-MJKjw4SzA-2v43QM', 'name': 'Kuukausittain hoidettavat', 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['1R5yETNNZjeCYqpzL8Zp-aKyPo4bH4trN'], 'id': '1cz-n21VperD5oClfLePOSljrYU1lKZ3B', 'name': 'Procountor-ohjeet muokattava 20_.docx.pdf', 'trashed': False}
# {'mimeType': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'parents': ['1R5yETNNZjeCYqpzL8Zp-aKyPo4bH4trN'], 'id': '1iuqS7VxQ1qroOH4qifxHTqLkxnd---4A', 'name': 'Procountor-ohjeet muokattava 20_.docx', 'trashed': False}
# {'mimeType': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'parents': ['1R5yETNNZjeCYqpzL8Zp-aKyPo4bH4trN'], 'id': '1tm0xcfpikVRILcifDIvrmIBtwc_9AlT1', 'name': 'Holvi _ Stripe -ohjeet muokattava 19_.docx', 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['1R5yETNNZjeCYqpzL8Zp-aKyPo4bH4trN'], 'id': '1uf5OGM-PsY1K6GkjpNwczi2DjDBbebXF', 'name': 'Holvi _ Stripe -ohjeet 19_.pdf', 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['1D67QQUAZREEyGOkWFQQxgvQpgK3ek-fO'], 'id': '1dCoNc8KYhq1svQ2Zt2gg421QxGY2bsnG', 'name': 'Katso-tunniste-Kertakäyttösalasanalista.pdf', 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['1V4JqcG8Wno9kMpyCj_mlc0vfqGti5DZ0'], 'id': '1VSWLn0zPv_EWbePxJPybtmIobraY9g1Z', 'name': 'YHTEISTYÖSOPIMUS_AALTOES_AALTO_Final_2020_Signed.pdf', 'trashed': False}
# {'mimeType': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'parents': ['1V4JqcG8Wno9kMpyCj_mlc0vfqGti5DZ0'], 'id': '1CZcW8NBw_0ZXi2izHhvrGsj_fmrWov7Z', 'name': 'Aaltoes_Privacy_Notice.docx', 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['1V4JqcG8Wno9kMpyCj_mlc0vfqGti5DZ0'], 'id': '1bPq5BnMbvrnSVH9ifVkt06E7gY3iGelr', 'name': 'Muutosilmoitus prh.pdf', 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['1V4JqcG8Wno9kMpyCj_mlc0vfqGti5DZ0'], 'id': '1QN8FJUevXyECkq4VrdBNzwb7KC8hH0P_', 'name': 'Aaltoes_Privacy_Notice.pdf', 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['1V4JqcG8Wno9kMpyCj_mlc0vfqGti5DZ0'], 'id': '16lgXRr97ATvkMFQwgJMC-TNYz9Z_Ju34', 'name': 'Aaltoes privacy policy.pdf', 'trashed': False}
# {'mimeType': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'parents': ['1V4JqcG8Wno9kMpyCj_mlc0vfqGti5DZ0'], 'id': '10AVxBFIEGQySbp9rMnjd8B9gHHgMapNo', 'name': 'Aaltoes privacy policy.docx', 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['1V4JqcG8Wno9kMpyCj_mlc0vfqGti5DZ0'], 'id': '1gLDtU7SgskZt1cvzYnf_sBxTB2MBSzaO', 'name': 'Aaltoes_Ticket_T_C.pdf', 'trashed': False}
# {'mimeType': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'parents': ['1V4JqcG8Wno9kMpyCj_mlc0vfqGti5DZ0'], 'id': '1__i7xswAQCfhCK_RWC7oMm8jFe6lRag9', 'name': 'Aaltoes Ticket Terms _ Conditions.docx', 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['1V4JqcG8Wno9kMpyCj_mlc0vfqGti5DZ0'], 'id': '1yW-Xm4jhgmDhFsdPGZYZRgVgYT-1bqFl', 'name': 'Aaltoes, verotuksellisia käytänteitä ja ohjeita.pdf', 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['1V4JqcG8Wno9kMpyCj_mlc0vfqGti5DZ0'], 'id': '1NLGyaNFLfCzya7lXUcKscZ5AntZTew6y', 'name': 'Katso_tunniste_Kertakayttosalasanalista.pdf', 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['16IdYyBy-oKmFycaBJCt6hAsF20EOT-LW'], 'id': '1pjCrFJvoSBKysWPvMpK5Uj_6BZy0ZHPa', 'name': "Testamentti 21'.pdf", 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['1bf6Wekdd8KGef56PI2GQZ70lsvhHYzcZ'], 'id': '1ZHDVKv63Lcleo5a4ogXSZAkLDsEHsNoVoshiwIz8bXo', 'name': 'Käteiskassakirja 2021', 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['1bf6Wekdd8KGef56PI2GQZ70lsvhHYzcZ'], 'id': '1McXAh4UxdEQ3WP_1slj0of2Xbz3uperZ', 'name': 'Todiste annetusta apurahasta.pdf', 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['1bf6Wekdd8KGef56PI2GQZ70lsvhHYzcZ'], 'id': '17arfFWzyrQLa1VBk8BxHuF7TDYtAVUoE', 'name': 'Me,_Cam_Tu_Nguyenova,_have_received_the_grant_from_Ignite_Aaltoes (1).pdf', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1aowjOll7n8Ju6ACtINXPUlZCoET3KTL7'], 'id': '1zd_6LDMzAoLm7U3tUcW9D_la6tPVQowdlsLgFqkDPXs', 'name': 'Reference: Marketing & communications contract 2018', 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['1CB4vjetOw9jFOnGuhZTlVUxsDwQLAkyz'], 'id': '1Jmej_aFEnh8EvddpM9_-C5LKFoNd_wv_', 'name': 'Aaltoes consulting contract Jiaqi Yang.pdf', 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['17fOwmtx0FsTaVs8y0YYVn-mR--EUr5Cr'], 'id': '1ymj01Nc4recz3bHEr2sMFsJK_IOfsnWd', 'name': 'Aaltoes consulting contract Ji Yang.pdf', 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['1-Crk4qdUSUxHCMvl3Jf403JzR3tIEQe2'], 'id': '1_42n1F6-mwZiqAQ6mEhN-UIx_kFMfVBm', 'name': 'TMI.Ji Yang.Series.pdf', 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['1-Crk4qdUSUxHCMvl3Jf403JzR3tIEQe2'], 'id': '1joNPbmggE4bQ-_3-CZ-TjBuwPIXHa7Uf', 'name': 'Maria Luu. Consultation..pdf', 'trashed': False}
# {'mimeType': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'parents': ['17fOwmtx0FsTaVs8y0YYVn-mR--EUr5Cr'], 'id': '1f1a80cLudBBVe5nCCHDv4Gxr7JpBQQ0b', 'name': 'Ji Yang_Series full time contract .docx', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['17fOwmtx0FsTaVs8y0YYVn-mR--EUr5Cr'], 'id': '1RTy5UcoDdsPuGbXdvg4ES9X7olhGmz7ehC-EX0Q_9eU', 'name': 'Maria Luu', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['17fOwmtx0FsTaVs8y0YYVn-mR--EUr5Cr'], 'id': '1T6uYTgAHozZjZV1dSB5c54BA4pkWq2_xGkToRvLBG4o', 'name': 'Ji Yang', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['17VXv9hsyeRA4e7cj9LmjEyR9ECjeoyv3'], 'id': '1efW4ivVHkEONFXjmUgGtkBZIbxObOVgBqNwf9iiL79o', 'name': 'juomatilaus Nokian Panimo', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1LQn2TJfRgIRlHo2S4sYD31iWs9HDc7nr'], 'id': '19SuGxFOinmLmhpA7sUyAjOA9gs6v7Pke5i-ZibybyBc', 'name': 'Tietokoneiden arvonmääritys', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['17VXv9hsyeRA4e7cj9LmjEyR9ECjeoyv3'], 'id': '18P-5eh9mxu0XynqydLch3HLJCFt0Wkccf8SWY46aw4Q', 'name': 'talouden strategiaesitys 8.6.2021', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['17VXv9hsyeRA4e7cj9LmjEyR9ECjeoyv3'], 'id': '10Eg31SIXvNziHIwTVmj48NXD6zBN7D70yGqSIFKEqYs', 'name': 'Norjan matka kulusuunnitelma', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['1prTb5OsS3RssHUWOSdOL8kJzXdwQEPE6'], 'id': '1GRmwZv0WrnGh4LRAHEX64gdoNYkKmoUlXCrARIEziWQ', 'name': 'Vuosibudjetti 2021 – Aaltoes', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['1prTb5OsS3RssHUWOSdOL8kJzXdwQEPE6'], 'id': '191yIyNPmJnbvlBMjDeiZkCoTl7YR9ubfnnzG-cpdCXo', 'name': 'Copy of Vuosibudjetti 2021 – Aaltoes', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['1prTb5OsS3RssHUWOSdOL8kJzXdwQEPE6'], 'id': '19nWWBppiRJWAzMXYnkrswZobMJ_TK0GD5bRCahQTXKk', 'name': '2021 - 2022 arvio', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['1pA9e4vUEnc7Zt7asOEHErXYwLZ_j_3lv'], 'id': '13y-p42-kHeL7PBfRmBd33Fgbv27-NZIrg5tXx-xBtqI', 'name': 'Kärkihanke', 'trashed': False}
# {'mimeType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'parents': ['1pA9e4vUEnc7Zt7asOEHErXYwLZ_j_3lv'], 'id': '1zGVCvOOEUhEUQpenJ7PEvLY0536tBfW9', 'name': 'Kärkkäri.xlsx', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['1pA9e4vUEnc7Zt7asOEHErXYwLZ_j_3lv'], 'id': '16OH-zwUOiaxZhSZryYe907agFFX649O79MqfHTU-iB8', 'name': 'output-5', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1S0-tROhW1h_kYQNAEPR6l0AfbFWeEykL'], 'id': '1BLysfO8pCET_xcpTFBo353fcTi6hq9kBealWwxkzMAI', 'name': 'Tilintarkastuskertomus 2020', 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['1S0-tROhW1h_kYQNAEPR6l0AfbFWeEykL'], 'id': '1u7Mmz4kWj6KmbctcWFWaJFQVTTgqPsV0', 'name': 'Allekirjoitettu, Vahvistusilmoituskirje.pdf', 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['1S0-tROhW1h_kYQNAEPR6l0AfbFWeEykL'], 'id': '1-0ciYhfNqqnZQCzEW-JWXbaJq3QOE0ra', 'name': 'Allekirjoitettu tilinpäätös 2020.pdf', 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['1S0-tROhW1h_kYQNAEPR6l0AfbFWeEykL'], 'id': '1tCcPKqywXLKFUjUxxL22TB6tz5wcEdi5', 'name': 'Tilintarkastuskertomus 2020.pdf', 'trashed': False}
# ...
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1UEtP9kccZ7T6FLicKl6_UEkgOEFKfWn3'], 'id': '1A4XzFlYIrz62XHUNdLKsej6nnnFW4tH9ReqmwBnN20o', 'name': 'Week 23 check-in', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1UEtP9kccZ7T6FLicKl6_UEkgOEFKfWn3'], 'id': '1bN1pD57146Jx-0F4neZn1cl7NJWjLDI1u1Yi_dJvyRU', 'name': 'Week 22 check-in', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1UEtP9kccZ7T6FLicKl6_UEkgOEFKfWn3'], 'id': '1_5ynXk08a3UZJygh5MmbRMctz9VINUaAFP_r0HBCz0g', 'name': 'Week 21 check-in', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1UEtP9kccZ7T6FLicKl6_UEkgOEFKfWn3'], 'id': '1qW_A4-taOS_Ma5ERHjV72dB7iw0siuw5dWr7EMndDyE', 'name': 'Week 20 check-in', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1UEtP9kccZ7T6FLicKl6_UEkgOEFKfWn3'], 'id': '18S0mklbh9yyzSEa0qzgzdVQ9F60SSfv70JWNDsZdRVw', 'name': 'Week 19 check-in', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1UEtP9kccZ7T6FLicKl6_UEkgOEFKfWn3'], 'id': '1Hs7iQccYzFu0lCmV5RpoER_aMYQUAu0CbEjbaBeZIow', 'name': 'Week 18 check-in', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1UEtP9kccZ7T6FLicKl6_UEkgOEFKfWn3'], 'id': '18AhQBVj6ynpMuBMwHTka88hMMrBTOFzK2wvE5Uu-Zko', 'name': 'Week 17 check-in', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1UEtP9kccZ7T6FLicKl6_UEkgOEFKfWn3'], 'id': '1wTNMZ4tXNTLSgsN78e7YDBd9XG9Ie2bwlzrKY8ag4rs', 'name': 'Week 16 check-in', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1UEtP9kccZ7T6FLicKl6_UEkgOEFKfWn3'], 'id': '1q6dg4eMmCEPKwSvfBm-a_VKHisPxY6eO9psnYcEUyx8', 'name': 'Week 15 check-in', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1UEtP9kccZ7T6FLicKl6_UEkgOEFKfWn3'], 'id': '1Xu_cFNB_ZifXk1BEDLn820tNfC9mgyVnkvsWXoE0j4k', 'name': 'Week 14 check-in', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1UEtP9kccZ7T6FLicKl6_UEkgOEFKfWn3'], 'id': '1R9CPOLKvQ5AQLIR_hamognNPF2fA1u3JVP2_Nbb0sLM', 'name': 'Week 13 check-in', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1UEtP9kccZ7T6FLicKl6_UEkgOEFKfWn3'], 'id': '1FKCkUs7OrrhfERZGrfRg_diwMbCaKr47stwEqctZdUE', 'name': 'Week 12 check-in', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1UEtP9kccZ7T6FLicKl6_UEkgOEFKfWn3'], 'id': '1tLZ5DEEYVjWuHKu8YwSXUL3SIhQYS5dTPxOnwR9rkUM', 'name': 'Week 11 check-in', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1UEtP9kccZ7T6FLicKl6_UEkgOEFKfWn3'], 'id': '1AfNYZZHnljdBaD6anGd00G6i7jx1Yv0DLhRTBoZsFJM', 'name': 'Week 10 check-in ', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1UEtP9kccZ7T6FLicKl6_UEkgOEFKfWn3'], 'id': '1FAwpb2CvtDXoYg6J2l-89AklM_JqHZ4C2xdmJmVuJtk', 'name': 'Week 9 check-in', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1UEtP9kccZ7T6FLicKl6_UEkgOEFKfWn3'], 'id': '1VgN6qvlKNixjybTiuMRWq1bFjVt7nPsGLCXs6aZ9jFE', 'name': 'Week 8 check-in', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1UEtP9kccZ7T6FLicKl6_UEkgOEFKfWn3'], 'id': '1Qv10ALcg05YU6jCrTZwVXsHgx3fNDC1x53sh8Z6bWAs', 'name': 'Week 7 check-in', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1UEtP9kccZ7T6FLicKl6_UEkgOEFKfWn3'], 'id': '1UjcoryiJmnCGNMsThf949gByJah436KiH3VUDAx51Ok', 'name': 'Week 6 check-in', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1UEtP9kccZ7T6FLicKl6_UEkgOEFKfWn3'], 'id': '1aCXyQQXJFOdFrj0yFOr_xgsI975ooNMzNoRc4x4QncY', 'name': 'Week 5 check-in', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1UEtP9kccZ7T6FLicKl6_UEkgOEFKfWn3'], 'id': '1AMoT66caV-1lfs8_jxH3NjHAen_hgwq0pibSapw380I', 'name': 'Week 4 check-in', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '1hlwvo0lY0SQVvbiGmkVYONR-nkUWZyKOpfgxwYNriuw', 'name': 'Week 46 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '1yQVmnOs0pYNMMryRCr1QWm0iKt1glyDkATbx0CACnbs', 'name': 'Week 45 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '1Yi11r5yi2GmzOrCPirYi6wCF5r-ExncxpDVUHC6ao3U', 'name': 'Week 43 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '170nNuOQcrb0iROlzlSXB8L5E89tErJvLiVGd8qpqgzQ', 'name': 'Week 42 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '1vrMzU_vMLz5VM6Ldq_VxtItpjQeoE4tAUtsB4QJODEc', 'name': 'Week 41 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '1f7pJ5TbTpOpNf021GCfr07l-Ot0NmZRgYojlNhKpMuI', 'name': 'Week 40 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '1N0_6raMMsjkwTDgt87Xfz66_AcrEPYswl9LJWEDUkU4', 'name': 'Week 39 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '180PU9cZdDORGBMe19YTFIssTJRz0qxJ0Q4VVKWrrkX4', 'name': '1. Check-out: Kopioi tämä uudelle viikolle!', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '17JbBkUyTxwQJ2IEktBJ7evpRMQhv21ousyZVD_FAj-w', 'name': 'Week 37 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '1EgaljNkoYHVL0m_i68rDTyDOoDItCz1obuQIDwkF_3Q', 'name': 'Week 36 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '1lakDzJ_44mVOu0HpRleoOQiasiHXZSNqOMYmCcz-p5M', 'name': 'Week 35 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '1E28cpdyn7Fjnea5ny5jvsmQLQAwpinUgDpI1tyctlbo', 'name': 'Week 34 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '1ownDLKplRIQyIJqC8BEucxLzzswuQrvA_fbljkL-xGc', 'name': 'Week 33 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '1d-nNie5Grpo7lZZwCM5yqfYvkxrjM4iKg_xtOO7udj8', 'name': 'Week 32 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '1adp-KUiq9vdD-b1cNE34gdsWyaGRpZn42gsk6TFkpv0', 'name': 'week 31 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '1qWej_9MXJQcsvdT5qfA03Ft5a2GmtieAWaPaFJo2huM', 'name': 'Week 30 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '11q-w0MBXPPNqKfPUGFXMDs_9alkU5z6rGPptF7Rd8DY', 'name': 'Week 29 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '13gZFOy-PvTDCmRQ6Ofn8wmphPwAEENY2qy3HyDvJK2o', 'name': 'Week 28 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '1y1Jgj4_y85m0erNDsiEPHn5rot-msBfHGQH1One7TMc', 'name': 'Week 25 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '1nhhzaVY9VRgWjk1xQ8awT0Bzayx-bB4HdWIOIrvf1RU', 'name': 'Week 24 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '1JhkZvFLEhDJ1GM8-qCaQCz8t-6Q5kC9qDbDHhf9F0kk', 'name': 'Week 23 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '1YTUKqUdKbsTTce2G3r96VNwUSfD_fY2wWkt_ja2dWf8', 'name': 'Week 22 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '1VK5NcgXS7wWULrjXM8fLmq-BRYLy1GUfkl3Ct3ki8xQ', 'name': 'Week 21 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '1GTLNZxjohCzEp9aKz4omMQk3gJUQfOv2s0UTZJ2J4IE', 'name': 'Week 20 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '1IgbjKlS-Ua87osRDs5WGqMWsbQpr_iAHl3UQrA0OScw', 'name': 'Week 19 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '1G_y5O_driL6RBda2HhasSWB1IgC9BQFR3cKO9-rNqZI', 'name': 'Week 18 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '1jR22hF-LQebywWFHTvzZ6aEnXO627XhR1HmFIxUI4Bc', 'name': 'Week 17 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '1q3-5ypOjVCAtO8u4gFGQ8PK4Y0PQq1T6dGTzkwLVGqA', 'name': 'Week 16 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '1DFPef5sp7O_INhHPD3NRcIk2nLVSgopP8Ge2rQpqOCU', 'name': 'week 15 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '1bRC-RK1spqEd2YwdjNWEoB4oCQd20NRZL5DfMNrVXJY', 'name': 'Week 14 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '1RWqdAoE3jQxO1A3jlwOkkSHrY2vpVKc9KsWSbFItm4Q', 'name': 'Week 13 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '1wPy5DRMf97eHOiJUFxWXSc_YqcI3wBHSpXoX7W5yEUM', 'name': 'Week 12 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '1zWgbUkn_JWaqOkoq43JJiwMvlL0Ibp0bSxRe_Uh7s5s', 'name': 'Week 11 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '1PEPoewwUl_5hiUNKlYEIc-WBqVTMrt5LY6itn1R-dWU', 'name': 'Week 10 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '1eoG0QhKby40Zwc4SPsbE2vTCqnaFIXbEPmdeWJ6R6RI', 'name': 'Week 9 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '1AlMwraJaTaVh0EOk5ldEcJ3WtBxbT0CVptytKKMqAM0', 'name': 'Week 8 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '1fvecsGMlw-bHX5OKMDI0N1IapHZSIstpAY2_J1kpAuY', 'name': 'Week 7 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '11y_T-87bo73jWTXcPg1JxW4QRmvd4MhCk0sR0EVDuHw', 'name': 'Week 6 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '1panrsKRuJGjltgKOKPIvgcRNf9EB98li42XEGfX35pk', 'name': 'Week 5 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '1Tc-2P7WGIX6oc_Cz-mC1ZRKHNFUeY56D84OJCxxMbVE', 'name': 'Week 4 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '1_k6UqLtkgdqj025Fxsms3DzWpXchxXrgXqwPRDTWuII', 'name': 'Week 3 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1iLI1UiS9yPnqD1eohK4QeuAFp3Nd86Q9'], 'id': '1NW4CYqn0HCf863BLtv-xRP5zCF9rw88bPFOHM6q6Qik', 'name': 'Week 2 check-out', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1UpY5TXlkOSNhTBwpEx9MNd9wPIUMC0fO'], 'id': '1pz6grfwMPz8yVhft9bdNmVlo0TrWpRPlAVn4kJIYu4A', 'name': 'Invitation to Annual Fall Meeting ', 'trashed': False}
# {'mimeType': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'parents': ['1UpY5TXlkOSNhTBwpEx9MNd9wPIUMC0fO'], 'id': '1Ts-C0YL3NLUSwIPQ3hM4xnkGjPXpRmHS', 'name': 'Aalto Entrepreneurship Society ry_n syyskokous 2021.docx', 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['1UpY5TXlkOSNhTBwpEx9MNd9wPIUMC0fO'], 'id': '1e_jGfqfwcy-ZexQeFg3BfWw5NSkNuHtM', 'name': 'Aalto Entrepreneurship Society ry_n syyskokous 2021.pdf', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1UpY5TXlkOSNhTBwpEx9MNd9wPIUMC0fO'], 'id': '1i8xLoR9BfGApGPdttu9UBCfptoPOer4iByAwcrTLJkc', 'name': 'Questions for the applicant', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1UpY5TXlkOSNhTBwpEx9MNd9wPIUMC0fO'], 'id': '18M4sg_1yn8w_TGloo_dYolm0mx8ENxiRK0dkwb3x1cU', 'name': 'Esityslista: Syyskokous 2021', 'trashed': False}
# {'mimeType': 'application/pdf', 'parents': ['1SHp-4LYP53QdcQJlOWaPVO1nPnDDx9g-'], 'id': '1fj97g8cDRNIr_0fwm1AYJZpSV4IKrw7x', 'name': '31.3 pöytäkirja kevätkokous .docx.pdf', 'trashed': False}
# {'mimeType': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'parents': ['1SHp-4LYP53QdcQJlOWaPVO1nPnDDx9g-'], 'id': '1PRnz-8hrGlkZ_xdkWBY-BuV_jRinpMBk', 'name': '31.3 pöytäkirja kevätkokous .docx', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.spreadsheet', 'parents': ['1SHp-4LYP53QdcQJlOWaPVO1nPnDDx9g-'], 'id': '10p3su1B31hJp6sNulxM47u3HVkqMRoIKeX3Ed4NBlIM', 'name': 'Osallistujalista', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.presentation', 'parents': ['1SHp-4LYP53QdcQJlOWaPVO1nPnDDx9g-'], 'id': '1lucvQ5cV9vArJqzJLfSwV8ESyq5P3BCEumodZfeYt8o', 'name': 'Kevätkokous 31.03.2021', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1EGgiVXxmPaEBs5wyNndEX04KCFEvkCJc'], 'id': '1SDQVl2w54gV-uIyzKeDnR7a10rGo_DgVAr6QJuIlRh4', 'name': 'Kevätkokous kutsu jäsenille', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['13HzTIL3fUVLQC1RcMwnZorAl0NoAm78R'], 'id': '1FtJ89oQMGJWnKmvJxDB6AGmCcY4klTNYjgEGzhmy3Xc', 'name': 'Aalto Entrepreneurship Society ry:n kevätkokous 2021 esityslista', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1WbWow5F3S7idlNlxlU2LpRcfWM8XywbM'], 'id': '1wTwGH3PEU9D6UMYAHby6Y6vyKh2PjxKrfcZ0wc3xU2A', 'name': 'Weekly checkout xx.xx.xxxx', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1xemnLF967Iv5mZ51YUcjG5UjR6v2k8Yf'], 'id': '1vF_Rm7zvOgslSoRE-PYqaf_I0x1SXTYuSVwwpm4nSlg', 'name': 'Toimintakertomus 2020', 'trashed': False}
# {'mimeType': 'application/vnd.google-apps.document', 'parents': ['1F1TJ06n0WjqCvyyEw30GZ-gUeBB_K_BR'], 'id': '1WBXYyGTbO3FvxSxLv3QHnisfYod_mfD_cacuR9_zSrc', 'name': 'Toimintakertomus 2020', 'trashed': False}

# %%
import pandas as pd

# Example data
df = pd.DataFrame(files_2018.copy())

def get_extension(file):
    temp = file['name'].split('.')[-1]
    if temp in {'docx', 'xlsx', 'pptx', 'pdf'}:
        return file['id'] + "_" + file['name'].split('/')[-1]
    
    mime_to_ext = {
        'application/vnd.google-apps.document': 'docx',        
        'application/vnd.google-apps.spreadsheet': 'xlsx',      
        'application/vnd.google-apps.presentation': 'pptx',
        'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet': 'xlsx', 
        'application/vnd.openxmlformats-officedocument.wordprocessingml.document': 'docx',
        'application/vnd.openxmlformats-officedocument.presentationml.presentation': 'pptx', 
        'application/pdf': 'pdf'
    }
    return file['id'] + "_" + file['name'].split('/')[-1] + "." + mime_to_ext[file['mimeType']]

# Apply get_extension to each row and update the 'name' column
df['name'] = df.apply(get_extension, axis=1)

# %%
import io
import os
from googleapiclient.http import MediaIoBaseDownload
from googleapiclient.errors import HttpError

# Mapping for native Google file types to primary export MIME types and file extensions.
# Exclude presentations because they are always exported as PDF.
export_mime_types = {
    'application/vnd.google-apps.document': (
        'application/vnd.openxmlformats-officedocument.wordprocessingml.document',
        'docx'
    ),
    'application/vnd.google-apps.spreadsheet': (
        'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet',
        'xlsx'
    )
}

# Alternative export mapping: exporting as PDF for all native Google files.
alternative_export_mime_types = {
    'application/vnd.google-apps.document': ('application/pdf', 'pdf'),
    'application/vnd.google-apps.spreadsheet': ('application/pdf', 'pdf'),
    'application/vnd.google-apps.presentation': ('application/pdf', 'pdf')
}

for index, row in df.iterrows():
    file_id = row['id']
    output_filename = row['name']  # This may include folder(s), e.g., "folder/file"
    mimeType = row['mimeType']

    try:
        if mimeType == 'application/vnd.google-apps.presentation':
            # Always export presentations as PDF.
            export_mime, ext = alternative_export_mime_types[mimeType]
            # Remove any existing extension and add PDF extension.
            base_name = os.path.splitext(output_filename)[0]
            output_filename = f"{base_name}.{ext}"
            request = service.files().export_media(fileId=file_id, mimeType=export_mime)
        elif mimeType in export_mime_types:
            export_mime, ext = export_mime_types[mimeType]
            # Append the extension if it's not already present.
            if not output_filename.endswith(ext):
                output_filename = f"{output_filename}.{ext}"
            request = service.files().export_media(fileId=file_id, mimeType=export_mime)
        else:
            # For non-native (binary) files.
            request = service.files().get_media(fileId=file_id)

        # Construct the full output path (base folder "2021" plus any nested folders in output_filename).
        full_path = os.path.join("2021", output_filename)
        # If the file already exists, skip downloading.
        if os.path.exists(full_path):
            print(f"File '{full_path}' already exists. Skipping download.")
            continue

        # Prepare to download the file.
        fh = io.BytesIO()
        downloader = MediaIoBaseDownload(fh, request)
        done = False
        while not done:
            status, done = downloader.next_chunk()
            print(f"Download {int(status.progress() * 100)}% for file '{output_filename}'.")

        # Create the directory structure if it doesn't exist.
        directory = os.path.dirname(full_path)
        if not os.path.exists(directory):
            os.makedirs(directory)
        
        # Write the downloaded file to disk.
        with open(full_path, "wb") as f:
            f.write(fh.getvalue())

    except HttpError as error:
        error_content = error.content.decode() if hasattr(error, 'content') else str(error)
        # For non-presentation files, if primary export fails due to size limit, try alternative export.
        if ("exportSizeLimitExceeded" in error_content and
            mimeType in alternative_export_mime_types and
            mimeType != 'application/vnd.google-apps.presentation'):
            print(f"Primary export failed for '{output_filename}' due to size limit. Trying alternative export as PDF.")
            alt_export_mime, alt_ext = alternative_export_mime_types[mimeType]
            base_name = os.path.splitext(output_filename)[0]
            output_filename = f"{base_name}.{alt_ext}"
            alt_full_path = os.path.join("2021", output_filename)
            if os.path.exists(alt_full_path):
                print(f"File '{alt_full_path}' already exists. Skipping alternative export.")
                continue
            try:
                request = service.files().export_media(fileId=file_id, mimeType=alt_export_mime)
                fh = io.BytesIO()
                downloader = MediaIoBaseDownload(fh, request)
                done = False
                while not done:
                    status, done = downloader.next_chunk()
                    print(f"Alternative download {int(status.progress() * 100)}% for file '{output_filename}'.")
                
                directory = os.path.dirname(alt_full_path)
                if not os.path.exists(directory):
                    os.makedirs(directory)
                
                with open(alt_full_path, "wb") as f:
                    f.write(fh.getvalue())
            except HttpError as alt_error:
                print(f"Alternative export also failed for file '{output_filename}' (ID: {file_id}): {alt_error}")
        else:
            print(f"Error downloading file '{output_filename}' (ID: {file_id}): {error}")
